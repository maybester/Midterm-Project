# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_excel('NBA_Stats_71_Years.xlsx')

# %%
df.head()
# Out:
#    Rank     Year  Season Start Year     Season Type  Player ID        Player  \
# 0     1  1951-52               1951  Regular Season      76056   Paul Arizin
# 1     2  1951-52               1951  Regular Season     600012  George Mikan
# 2     3  1951-52               1951  Regular Season     600003     Bob Cousy
# 3     4  1951-52               1951  Regular Season      77429   Ed Macauley
# 4     5  1951-52               1951  Regular Season      76514    Bob Davies
#
#       Team ID Team  Games Played  Minutes Played  ...  Rebounds  Assists  \
# 0  1610612744  PHW            66            2939  ...       745      170
# 1  1610612747  MNL            64            2572  ...       866      194
# 2  1610612738  BOS            66            2681  ...       421      441
# 3  1610612738  BOS            66            2631  ...       529      232
# 4  1610612758  ROC            65            2394  ...       189      390
#
# ...

# %%
df.shape
# Out:
# (33329, 31)

# %%
df.isnull().sum()
# Out:
# Rank                     0
# Year                     0
# Season Start Year        0
# Season Type              0
# Player ID                0
# Player                   0
# Team ID                  0
# Team                     0
# Games Played             0
# Minutes Played           0
# FG Made                  0
# FG Attempts              0
# FG %                     0
# 3-Pt FG Made          6296
# 3-Pt FG Attempts      6296
# 3-Pt FG %             6296
# FT Made                  0
# FT Attempts              0
# FT %                     0
# Offensive Rebounds    4229
# Defensive Rebounds    4229
# Rebounds                 0
# Assists                  0
# Steals                4229
# Blocks                4229
# Turnovers             5566
# Personal Fouls           0
# Points Scored            0
# Efficency                0
# AST/TOV               5566
# STL/TOV               5566
# dtype: int64

# %% [markdown]
# ### Replacing all null values with their mean

# %%
df['3-Pt FG Attempts'] = df['3-Pt FG Attempts'].fillna(df['3-Pt FG Attempts'].mean())
df['3-Pt FG %'] = df['3-Pt FG %'].fillna(df['3-Pt FG %'].mean())
df['3-Pt FG Made'] = df['3-Pt FG Made'].fillna(df['3-Pt FG Made'].mean())
df['Offensive Rebounds'] = df['Offensive Rebounds'].fillna(df['Offensive Rebounds'].mean())
df['Defensive Rebounds'] = df['Defensive Rebounds'].fillna(df['Defensive Rebounds'].mean())
df['Steals'] = df['Steals'].fillna(df['Steals'].mean())
df['Blocks'] = df['Blocks'].fillna(df['Blocks'].mean())
df['Turnovers'] = df['Turnovers'].fillna(df['Turnovers'].mean())
df['AST/TOV'] = df['AST/TOV'].fillna(df['AST/TOV'].mean())
df['STL/TOV'] = df['STL/TOV'].fillna(df['STL/TOV'].mean())

# %%
df.shape
# Out:
# (33329, 31)

# %%
df.isnull().sum()
# Out:
# Rank                  0
# Year                  0
# Season Start Year     0
# Season Type           0
# Player ID             0
# Player                0
# Team ID               0
# Team                  0
# Games Played          0
# Minutes Played        0
# FG Made               0
# FG Attempts           0
# FG %                  0
# 3-Pt FG Made          0
# 3-Pt FG Attempts      0
# 3-Pt FG %             0
# FT Made               0
# FT Attempts           0
# FT %                  0
# Offensive Rebounds    0
# Defensive Rebounds    0
# Rebounds              0
# Assists               0
# Steals                0
# Blocks                0
# Turnovers             0
# Personal Fouls        0
# Points Scored         0
# Efficency             0
# AST/TOV               0
# STL/TOV               0
# dtype: int64

# %%
df['Season Type'] = df['Season Type'].astype('category')
df['Season Type'] = df['Season Type'].cat.codes
df
# Out:
#        Rank     Year  Season Start Year  Season Type  Player ID  \
# 0         1  1951-52               1951            1      76056
# 1         2  1951-52               1951            1     600012
# 2         3  1951-52               1951            1     600003
# 3         4  1951-52               1951            1      77429
# 4         5  1951-52               1951            1      76514
# ...     ...      ...                ...          ...        ...
# 33324   194  2022-23               2022            0     203496
# 33325   194  2022-23               2022            0     203648
# 33326   194  2022-23               2022            0       2617
# 33327   194  2022-23               2022            0    1628427
# 33328   194  2022-23               2022            0    1631111
#
#                        Player     Team ID Team  Games Played  Minutes Played  \
# 0                 Paul Arizin  1610612744  PHW            66            2939
# ...

# %%
#Training Features
X = df.drop(columns = ['Rank', 'Season Start Year', 'Year', 'Player', 'Team', 'Team ID', 'Player ID'])
X
# Out:
#        Season Type  Games Played  Minutes Played  FG Made  FG Attempts   FG %  \
# 0                1            66            2939      548         1222  0.448
# 1                1            64            2572      545         1414  0.385
# 2                1            66            2681      512         1388  0.369
# 3                1            66            2631      384          888  0.432
# 4                1            65            2394      379          990  0.383
# ...            ...           ...             ...      ...          ...    ...
# 33324            0             2              12        0            3  0.000
# 33325            0             2               5        0            0  0.000
# 33326            0             1               2        0            2  0.000
# 33327            0             4              10        0            5  0.000
# 33328            0             1               2        0            0  0.000
#
# ...

# %%
#Label
y = df['Rank']

# %%
from sklearn.model_selection import train_test_split

# %%
#Splitting our dataset using 30% of our data as test zize
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 21)

# %%
X_train
# Out:
#        Season Type  Games Played  Minutes Played  FG Made  FG Attempts   FG %  \
# 7513             1            70            2531      684         1309  0.523
# 17980            1            13              44        6           24  0.250
# 29394            0             6             151       13           25  0.520
# 15100            1            80            2804      550         1214  0.453
# 6486             1            68             869       88          250  0.352
# ...            ...           ...             ...      ...          ...    ...
# 16432            1            50            1156      168          371  0.453
# 8964             1            68            2397      561          978  0.574
# 5944             1            82            2941      707         1424  0.496
# 5327             1            59            1354      182          436  0.417
# 15305            1            72            1061      140          333  0.420
#
# ...

# %%
X_test
# Out:
#        Season Type  Games Played  Minutes Played  FG Made  FG Attempts   FG %  \
# 26495            0             7             267       44          102  0.431
# 9244             1             2               2        0            2  0.000
# 4180             0             5             211       43           85  0.506
# 3187             1            71            2544      620         1376  0.451
# 9769             0            15             562      134          297  0.451
# ...            ...           ...             ...      ...          ...    ...
# 8407             0             3              17        7           12  0.583
# 9160             1            58             469       74          167  0.443
# 1296             0             3             118       28           60  0.467
# 18552            1            23             181       26           63  0.413
# 18980            1            73            1931      231          467  0.495
#
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
#Fitting our training data
lr = LinearRegression().fit(X_train, y_train)

# %%
# Y intercept
c = lr.intercept_

# %%
c
# Out:
# 186.9824207291699

# %%
# Coeficient
m = lr.coef_
m
# Out:
# array([ 2.59593879e+02, -9.25402457e-01, -2.84667164e-02, -8.25453724e+00,
#         3.35497385e-01, -4.81533935e+01, -4.78076006e+00,  2.53065064e-01,
#         6.37693158e-01, -4.17660867e+00,  2.23810128e-01, -5.05010907e+01,
#        -4.83272111e-02, -8.19085767e-02, -4.32652872e-01, -4.15807640e-01,
#        -5.19374321e-01, -4.40019670e-01,  1.56190703e-01, -9.74279771e-02,
#         3.44083230e+00,  5.06246974e-01, -5.22680914e+00,  6.15534832e+00])

# %%
#Prediction using our training data
y_pred_train = lr.predict(X_train)
y_pred_train
# Out:
# array([ 11.3975288 , 369.33221911, 104.92735805, ..., -87.3065408 ,
#        138.15464858, 230.54141758])

# %%
import matplotlib.pyplot as plt
plt.scatter(y_train, y_pred_train)
plt.xlabel('Actual Rank')
plt.ylabel('Predicted Rank')
plt.show()

# %%
from sklearn.metrics import r2_score

# %%
#Checking R2 Score
r2_score(y_train, y_pred_train)
# Out:
# 0.8724677095038642

# %%
#Predict using our test data
y_pred_test = lr.predict(X_test)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test, y_pred_test)
plt.xlabel('Actual Rank')
plt.ylabel('Predicted Rank')
plt.show()

# %%
r2_score(y_test, y_pred_test)
# Out:
# 0.8735570647487618
